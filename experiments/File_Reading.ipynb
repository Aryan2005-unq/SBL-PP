# %% [markdown]
# To implement a Python program to count the number of lines, words and characters in a file.

# %%
if __name__ == '__main__':
  with open('./naruto.txt','r') as file:
    lines = file.readlines()
    words = sum(len(line.split()) for line in lines)
    characters = sum(len(line) for line in lines)
    len_lines = len(lines)


print(f"number of lines are: {len(lines)}")
print(f"number of words are: {words}")
print(f"number of characters are :{characters}")
# Out:
# number of lines are: ['Naruto Uzumaki is a young ninja from the Hidden Leaf Village (Konohagakure) who dreams of becoming the Hokage,\n', 'the leader of his village, to gain recognition and respect from everyone. \n', 'Born as the son of the Fourth Hokage, Minato Namikaze, and Kushina Uzumaki, Naruto had a difficult childhood. \n', 'He was orphaned at birth and grew up as an outcast because the Nine-Tails Fox (Kurama),\n', 'a powerful and destructive beast, was sealed inside him. Despite the loneliness and hardship, Naruto never gave up on his dreams.']
# number of words are: 85
# number of characters are :514
